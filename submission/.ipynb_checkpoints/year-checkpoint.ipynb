# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hour_df = pd.read_csv("https://raw.githubusercontent.com/adibfloat/Dicoding-BADDP-Proyek-Analisis-Data/main/submission/data/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
day_df = pd.read_csv("https://raw.githubusercontent.com/adibfloat/Dicoding-BADDP-Proyek-Analisis-Data/main/submission/data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# ASSESSING DATA

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    object
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(10), object(2)
# memory usage: 91.5+ KB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi pada hour_df: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi pada hour_df:  0

# %%
print("Jumlah duplikasi pada day_df: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi pada day_df:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
day_df.describe()
# Out:
#           instant      season        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    6.519836    0.028728    2.997264    0.683995
# std    211.165812    1.110807    3.451913    0.167155    2.004787    0.465233
# min      1.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%    183.500000    2.000000    4.000000    0.000000    1.000000    0.000000
# 50%    366.000000    3.000000    7.000000    0.000000    3.000000    1.000000
# 75%    548.500000    3.000000   10.000000    0.000000    5.000000    1.000000
# max    731.000000    4.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# min      1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      2.000000    0.655417    0.608602    0.730209    0.233214
# max      3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %%
# Cleaning Data

# %%
hour_df["dteday"] = pd.to_datetime(hour_df["dteday"])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
day_df["dteday"] = pd.to_datetime(day_df["dteday"])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    object
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(10), object(1)
# memory usage: 91.5+ KB

# %%
# Exploratory Data Analysis (EDA)
# Explore day_df

# %%
day_df.sample(5)
# Out:
#      instant     dteday  season    yr  mnth  holiday  weekday  workingday  \
# 108      109 2011-04-19       2  2011     4        0        2           1
# 19        20 2011-01-20       1  2011     1        0        4           1
# 139      140 2011-05-20       2  2011     5        0        5           1
# 72        73 2011-03-14       1  2011     3        0        1           1
# 272      273 2011-09-30       4  2011     9        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 108           2  0.505833  0.489258  0.665833   0.157971     409        2795
# 19            2  0.261667  0.255050  0.538333   0.195904      83        1844
# 139           1  0.536667  0.529042  0.719583   0.125013     909        4008
# 72            1  0.325217  0.332000  0.496957   0.136926     359        1687
# 272           1  0.564167  0.544829  0.647500   0.206475     830        4372
#
#       cnt
# 108  3204
# 19   1927
# 139  4917
# 72   2046
# 272  5202

# %%
day_df.describe(include="all")
# Out:
#            instant               dteday      season    yr        mnth  \
# count   731.000000                  731  731.000000   731  731.000000
# unique         NaN                  NaN         NaN     2         NaN
# top            NaN                  NaN         NaN  2012         NaN
# freq           NaN                  NaN         NaN   366         NaN
# mean    366.000000  2012-01-01 00:00:00    2.496580   NaN    6.519836
# min       1.000000  2011-01-01 00:00:00    1.000000   NaN    1.000000
# 25%     183.500000  2011-07-02 12:00:00    2.000000   NaN    4.000000
# 50%     366.000000  2012-01-01 00:00:00    3.000000   NaN    7.000000
# 75%     548.500000  2012-07-01 12:00:00    3.000000   NaN   10.000000
# max     731.000000  2012-12-31 00:00:00    4.000000   NaN   12.000000
# std     211.165812                  NaN    1.110807   NaN    3.451913
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.028728    2.997264    0.683995    1.395349    0.495385
# min       0.000000    0.000000    0.000000    1.000000    0.059130
# 25%       0.000000    1.000000    0.000000    1.000000    0.337083
# 50%       0.000000    3.000000    1.000000    1.000000    0.498333
# 75%       0.000000    5.000000    1.000000    2.000000    0.655417
# max       1.000000    6.000000    1.000000    3.000000    0.861667
# std       0.167155    2.004787    0.465233    0.544894    0.183051
#
#              atemp         hum   windspeed       casual   registered  \
# count   731.000000  731.000000  731.000000   731.000000   731.000000
# unique         NaN         NaN         NaN          NaN          NaN
# top            NaN         NaN         NaN          NaN          NaN
# freq           NaN         NaN         NaN          NaN          NaN
# mean      0.474354    0.627894    0.190486   848.176471  3656.172367
# min       0.079070    0.000000    0.022392     2.000000    20.000000
# 25%       0.337842    0.520000    0.134950   315.500000  2497.000000
# 50%       0.486733    0.626667    0.180975   713.000000  3662.000000
# 75%       0.608602    0.730209    0.233214  1096.000000  4776.500000
# max       0.840896    0.972500    0.507463  3410.000000  6946.000000
# std       0.162961    0.142429    0.077498   686.622488  1560.256377
#
#                 cnt
# count    731.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    4504.348837
# min       22.000000
# 25%     3152.000000
# 50%     4548.000000
# 75%     5956.000000
# max     8714.000000
# std     1937.211452

# %%
day_df.loc[day_df["season"] == 1, "season"] = "Musim Semi"
day_df.loc[day_df["season"] == 2, "season"] = "Musim Panas"
day_df.loc[day_df["season"] == 3, "season"] = "Musim Gugur"
day_df.loc[day_df["season"] == 4, "season"] = "Musim Dingin"

day_df.season.value_counts().sort_index(ascending=False)
# Out:
# season
# Musim Semi      181
# Musim Panas     184
# Musim Gugur     188
# Musim Dingin    178
# Name: count, dtype: int64

# %%
day_df.loc[day_df["yr"] == 0, "yr"] = "2011"
day_df.loc[day_df["yr"] == 1, "yr"] = "2012"

day_df.yr.value_counts().sort_index()
# Out:
# yr
# 2011    365
# 2012    366
# Name: count, dtype: int64

# %%
day_df.mnth.value_counts().sort_index()
# Out:
# mnth
# 1     62
# 2     57
# 3     62
# 4     60
# 5     62
# 6     60
# 7     62
# 8     62
# 9     60
# 10    62
# 11    60
# 12    62
# Name: count, dtype: int64

# %%
day_df.loc[day_df["holiday"] == 0, "holiday"] = "Libur"
day_df.loc[day_df["holiday"] == 1, "holiday"] = "Tidak ada hari libur"

day_df.holiday.value_counts().sort_index()
# Out:
# holiday
# Libur                   710
# Tidak ada hari libur     21
# Name: count, dtype: int64

# %%
day_df.loc[day_df["weekday"] == 0, "weekday"] = "Minggu"
day_df.loc[day_df["weekday"] == 1, "weekday"] = "Senin"
day_df.loc[day_df["weekday"] == 2, "weekday"] = "Selasa"
day_df.loc[day_df["weekday"] == 3, "weekday"] = "Rabu"
day_df.loc[day_df["weekday"] == 4, "weekday"] = "Kamis"
day_df.loc[day_df["weekday"] == 5, "weekday"] = "Jumat"
day_df.loc[day_df["weekday"] == 6, "weekday"] = "Sabtu"

day_df.weekday.value_counts().sort_index()
# Out:
# weekday
# Jumat     104
# Kamis     104
# Minggu    105
# Rabu      104
# Sabtu     105
# Selasa    104
# Senin     105
# Name: count, dtype: int64

# %%
day_df.loc[day_df["workingday"] == 0, "workingday"] = "Hari Libur"
day_df.loc[day_df["workingday"] == 1, "workingday"] = "Hari Bekerja"

day_df.workingday.value_counts().sort_index()
# Out:
# workingday
# Hari Bekerja    500
# Hari Libur      231
# Name: count, dtype: int64

# %%
day_df.loc[day_df["weathersit"] == 1, "weathersit"] = "Terang"
day_df.loc[day_df["weathersit"] == 2, "weathersit"] = "Berkabut"
day_df.loc[day_df["weathersit"] == 3, "weathersit"] = "Bersalju Tipis"
day_df.loc[day_df["weathersit"] == 4, "weathersit"] = "Hujan Deras"

day_df.weathersit.value_counts().sort_index()
# Out:
# weathersit
# Berkabut          247
# Bersalju Tipis     21
# Terang            463
# Name: count, dtype: int64

# %%
# Explore hour_df

# %%
hour_df.hr.value_counts().sort_index()
# Out:
# hr
# 0     726
# 1     724
# 2     715
# 3     697
# 4     697
# 5     717
# 6     725
# 7     727
# 8     727
# 9     727
# 10    727
# 11    727
# 12    728
# 13    729
# 14    729
# 15    729
# 16    730
# 17    730
# 18    728
# 19    728
# 20    728
# 21    728
# 22    728
# 23    728
# Name: count, dtype: int64

# %%
hour_df.loc[hour_df["weathersit"] == 1, "weathersit"] = "Terang"
hour_df.loc[hour_df["weathersit"] == 2, "weathersit"] = "Berkabut"
hour_df.loc[hour_df["weathersit"] == 3, "weathersit"] = "Bersalju Tipis"
hour_df.loc[hour_df["weathersit"] == 4, "weathersit"] = "Hujan Deras"

hour_df.weathersit.value_counts().sort_index()
# Out:
# weathersit
# Berkabut           4544
# Bersalju Tipis     1419
# Hujan Deras           3
# Terang            11413
# Name: count, dtype: int64

# %%
# Visualisasi & Analisis Penjelasan
# Bagaimana pengaruh musim terhadap penyewaan sepeda?

# %%
byseason_df = day_df.groupby(by="season").instant.nunique().reset_index()
byseason_df.rename(columns={
    "season": "musim",
    "instant": "sum"
}, inplace=True)
byseason_df
# Out:
#    musim  sum
# 0      1  181
# 1      2  184
# 2      3  188
# 3      4  178

# %%
byyear_df = day_df.groupby(by="yr").instant.nunique().reset_index()
byyear_df.rename(columns={
    "yr": "tahun",
    "instant": "jumlah"
}, inplace=True)
byyear_df
# Out:
#   tahun  jumlah
# 0  2011     365
# 1  2012     366

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y="jumlah",
    x="tahun",
    data=byyear_df.sort_values(by="tahun", ascending=False),
)
plt.title("Jumlah Pembagian Sepeda Berdasarkan Tahun", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis="x", labelsize=12)
plt.show()
